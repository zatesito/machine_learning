# %% [markdown]
# ## variables and arrays

# %%
import numpy as np

# %%
array_1 = np.array([0,1,2,3])
array_2 = np.array(np.random.randint(0,10,len(array_1)))

print(array_1,array_2)
print(array_1.shape,array_2.shape)
# Out:
# [0 1 2 3] [7 2 1 8]
# (4,) (4,)

# %%
array_s = array_1 + array_2
print(array_s, type(array_s))
# Out:
# [ 7  3  3 11] <class 'numpy.ndarray'>

# %%
array_1[3] = 70
print(array_1 + array_2 )
# Out:
# [ 7  3  3 78]

# %%
array_m = array_1 * array_2
array_d= np.dot(array_1, array_2)
print(array_m, array_d)
print(array_m)
# Out:
# [  0   2   2 560] 564
# [  0   2   2 560]

# %% [markdown]
# IMAGES

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img = cv2.imread("/content/lena.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

print(type(img), img.shape)
# Out:
# <class 'numpy.ndarray'> (300, 400, 3)

# %%
print(img[0, 0:10,1 ])
# Out:
# [ 6 10  0  7  2  0  0  7  5  6]

# %%
img[0:50, 0:50,0] = 0
img[0:50, 0:50,1] = 0
img[0:50, 0:50,2] = 0
plt.imshow(img)

# %%
lena_face= (img[100:200,170:270,0:3])
plt.imshow(lena_face)

# %%
img[50:150,20:120,0:3] = lena_face
plt.imshow(img)
